# %%
import chess
import chess.svg
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from IPython.display import display, Image ,clear_output
from stockfish import Stockfish
import tensorflow as tf
# Out:
# 2023-09-30 18:14:38.440870: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-30 18:14:39.548129: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from tensorflow.keras.models import load_model
player1=load_model('santoyant.h5')
# Out:
# 2023-09-30 18:14:41.557487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:41.671398: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:41.671476: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:41.673506: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:41.673574: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:41.673604: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:42.823311: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:42.823389: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:42.823398: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1726] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-09-30 18:14:42.823432: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-30 18:14:42.823480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3888 MB memory:  -> device: 0, name: Quadro RTX 3000, pci bus id: 0000:01:00.0, compute capability: 7.5
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from copy import deepcopy

# %%
def fen_to_board(fen):
    board = []
    for row in fen.split('/'):
        brow = []
        for c in row:
            if c == ' ':
                break
            elif c in '12345678':
                brow.extend( ['--'] * int(c) )
            elif c == 'p':
                brow.append( 'bp' )
            elif c == 'P':
                brow.append( 'wp' )
            elif c > 'Z':
                brow.append( 'b'+c.upper() )
            else:
                brow.append( 'w'+c )

        board.append( brow )
    return board

# %%
class Envi():
    def __init__(self,intial_fen):
        self.stockfish=Stockfish("./stockfish-ubuntu-x86-64-avx2",parameters={"Hash":2048})
        self.stockfish.set_skill_level(7)
        if intial_fen == "":
            self.board = chess.Board()
        else:
            self.board = chess.Board(intial_fen)
            self.stockfish.set_fen_position(intial_fen)
        fen=self.board.fen()
        text=fen_to_board(fen)
        self.tokenizer=Tokenizer()
        self.tokenizer.fit_on_texts(text)
        self.movestack=[]
        self.movestack2=[]
        self.boardprev=deepcopy(self.board)

    def step(self,action):
        r=50
        if len(self.movestack)>4:
            self.movestack.pop(0)
        if action in self.movestack:
            action=self.legal()[np.random.randint(len(self.legal()))]
        self.movestack.append(action)
        self.stockfish.set_fen_position(self.board.fen())
        self.board.push(action)
        if str(self.stockfish.will_move_be_a_capture(action.uci()).name)!="NO_CAPTURE":
            r=r+500
        self.stockfish.set_fen_position(self.board.fen())
        action=self.act_to_encod(action)
        self.boardprev=deepcopy(self.board)
        playermove=self.getbestmove()
        if playermove==None:
            return self.prevstate(),50000,self.brd,1,action
        if str(self.stockfish.will_move_be_a_capture(playermove.uci()).name)!="NO_CAPTURE":
            r=r-500
        self.board.push(playermove)
        self.brd=self.state()
        # if self.boardprev.is_checkmate():
        #     return 10000,self.brd,1,action
        # elif self.boardprev.is_stalemate():
        #     return 10,self.brd,1,action
        # elif self.boardprev.is_insufficient_material():
        #     return 10,self.brd,1,action
        # elif self.boardprev.can_claim_draw():
        #     return 10,self.brd,1,action
        # elif self.boardprev.is_check():
        #     return 5000,self.brd,0,action
        # elif self.board.is_checkmate():
        #     return -500,self.brd,1,action
        # elif self.board.is_check():
        #     return -200,self.brd,0,action
        # else:
        #     return r,self.brd,0,action
        if self.boardprev.is_checkmate():
            return self.prevstate(),1000000,self.brd,1,action
        elif self.boardprev.is_stalemate():
            return self.prevstate(),10,self.brd,1,action
        elif self.boardprev.is_insufficient_material():
            return self.prevstate(),10,self.brd,1,action
        elif self.boardprev.can_claim_draw():
            return self.prevstate(),100,self.brd,1,action
        elif self.boardprev.is_check():
            return self.prevstate(),3000,self.brd,0,action
        elif self.board.is_checkmate():
            return self.prevstate(),-5000,self.brd,1,action
        elif self.board.is_check():
            return self.prevstate(),-3000,self.brd,0,action
        # elif self.board.can_claim_threefold_repetition():
        #     return -10000,self.brd,1,action
        else:
            return self.prevstate(),r,self.brd,0,action
    
    def stepc(self,action):
        self.board.push(action)
        action=self.act_to_encod(action)
        self.brd=self.state()
        if self.board.is_checkmate():
            return self.prevstate(),1000,self.brd,1,action
        if self.board.can_claim_threefold_repetition():
            return self.prevstate(),10,self.brd,1,action
        elif self.board.is_stalemate():
            return self.prevstate(),10,self.brd,1,action
        elif self.board.is_insufficient_material():
            return self.prevstate(),10,self.brd,1,action
        elif self.board.can_claim_draw():
            return self.prevstate(),10,self.brd,1,action
        elif self.board.is_check():
            return self.prevstate(),10,self.brd,0,action
        else:
            return self.prevstate(),0,self.brd,0,action
    
    def getbestmove(self):
        while not self.board.is_game_over():
            lmoves=self.legal()
            if len(lmoves)==0:
                return None
            else:
                q=[]
                for i in self.legal():
                    new_state=self.stepc2(i)
                    self.board.pop()
                    q.append(new_state)
                new_states=tf.convert_to_tensor(q,dtype=tf.float32)
                # new_states = np.expand_dims(new_states, axis=0)
                state_qn=player1(new_states)
                movep=self.legal()[np.argmax(state_qn)]
                if self.movestack2.count(movep)>3:
                    self.movestack2.pop(0)
                if movep in self.movestack2:
                    movep=self.legal()[np.random.randint(len(self.legal()))]
                self.movestack2.append(movep)
                print("Computer move",movep)
                return movep
    
    def stepc2(self,action):
        if action not in self.legal():
            print("Illegal move")
            return
        else:
            self.board.push(action)
            self.brd=self.state()
            return self.brd
    
    def act_to_encod(self,action):
        # move=chess.Move.from_uci(action)
        move=action
        return [move.from_square,move.to_square]
    
    def state(self):
        fen=self.board.fen()
        text=fen_to_board(fen)
        seq=self.tokenizer.texts_to_sequences(text)
        self.brd=np.array(seq).reshape(64)
        return self.brd
    
    def prevstate(self):
        fen=self.boardprev.fen()
        text=fen_to_board(fen)
        seq=self.tokenizer.texts_to_sequences(text)
        self.b=np.array(seq).reshape(64)
        return self.b
        
    def legal(self):
        self.pmoves=[x for x in self.board.legal_moves]
        return self.pmoves

    def reset(self):
        self.board.reset()
        return self.board.fen()

# %%
import tensorflow as tf
import numpy as np
import time
import random
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.losses import MSE
from tensorflow.keras.optimizers import Adam
from collections import deque, namedtuple

# %%
MEMORY_SIZE = 100_000     # size of memory buffer
GAMMA = 0.75          # discount factor
ALPHA = 3e-3              # learning rate  
NUM_STEPS_FOR_UPDATE = 4  # perform a learning update every C time steps
TAU = 1                # soft update of target parameters

# %%
frontmodel="nanoyant.h5"

# %%
def mul(a,b):
    return a*b

# %%
a=Input(shape=(128,))
x=tf.keras.layers.Lambda(lambda x:x[:65])(a)
y=tf.keras.layers.Lambda(lambda x:x[64:])(a)
y=tf.keras.layers.Lambda(lambda x:tf.reshape(x,(8,8,1)))(y)
y=tf.keras.layers.Conv1D(filters=8,kernel_size=3,activation='relu')(y)
y=tf.keras.layers.MaxPooling1D(pool_size=1)(y)
y=tf.keras.layers.Conv1D(filters=32,kernel_size=3,activation='relu')(y)
y=tf.keras.layers.MaxPooling1D(pool_size=2)(y)
y=tf.keras.layers.Dense(units=64,activation='linear')(y)
z=tf.keras.layers.Lambda(lambda x:x[0]*x[1])([x,y])
z=tf.keras.layers.Lambda(lambda x:tf.expand_dims(x,axis=0))(z)
z=Dense(128,activation="relu")(z)
z=Dense(64,activation="relu")(z)
z=Dense(32,activation="relu")(z)
z=Dense(1,activation="linear")(z)
q_network=tf.keras.models.Model(inputs=[x,y],outputs=z)


a=Input(shape=(128,))
x=tf.keras.layers.Lambda(lambda x:x[:65])(a)
y=tf.keras.layers.Lambda(lambda x:x[65:])(a)
y=tf.keras.layers.Lambda(lambda x:tf.reshape(x,(8,8,1)))(y)
y=tf.keras.layers.Conv1D(filters=8,kernel_size=3,activation='relu')(y)
y=tf.keras.layers.MaxPooling1D(pool_size=1)(y)
y=tf.keras.layers.Conv1D(filters=32,kernel_size=3,activation='relu')(y)
y=tf.keras.layers.MaxPooling1D(pool_size=2)(y)
y=tf.keras.layers.Dense(units=64,activation='linear')(y)
z=tf.keras.layers.Lambda(lambda x:x[0]*x[1])([x,y])
z=tf.keras.layers.Lambda(lambda x:tf.expand_dims(x,axis=0))(z)
z=Dense(128,activation="relu")(z)
z=Dense(64,activation="relu")(z)
z=Dense(32,activation="relu")(z)
z=Dense(1,activation="linear")(z)
target_q_network=tf.keras.models.Model(inputs=[x,y],outputs=z)

otimizer=Adam(learning_rate=ALPHA)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       2 x=tf.keras.layers.Lambda(lambda x:x[:65])(a)
#       3 y=tf.keras.layers.Lambda(lambda x:x[64:])(a)
# ----> 4 y=tf.keras.layers.Lambda(lambda x:tf.reshape(x,(8,8,1)))(y)
#       5 y=tf.keras.layers.Conv1D(filters=8,kernel_size=3,activation='relu')(y)
#       6 y=tf.keras.layers.MaxPooling1D(pool_size=1)(y)
#
# File ~/miniconda3/envs/tfg/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In[10], line 4, in <lambda>(x)
#       2 x=tf.keras.layers.Lambda(lambda x:x[:65])(a)
#       3 y=tf.keras.layers.Lambda(lambda x:x[64:])(a)
# ----> 4 y=tf.keras.layers.Lambda(lambda x:tf.reshape(x,(8,8,1)))(y)
#       5 y=tf.keras.layers.Conv1D(filters=8,kernel_size=3,activation='relu')(y)
#       6 y=tf.keras.layers.MaxPooling1D(pool_size=1)(y)
#
# ValueError: Exception encountered when calling layer "lambda_2" (type Lambda).
#
# Dimension size must be evenly divisible by 128 but is 64 for '{{node lambda_2/Reshape}} = Reshape[T=DT_FLOAT, Tshape=DT_INT32](Placeholder, lambda_2/Reshape/shape)' with input shapes: [?,128], [3] and with input tensors computed as partial shapes: input[1] = [8,8,1].
#
# Call arguments received by layer "lambda_2" (type Lambda):
#   • inputs=tf.Tensor(shape=(None, 128), dtype=float32)
#   • mask=None
#   • training=None

# %%
q_network.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 q_network.summary()
#
# NameError: name 'q_network' is not defined

# %%
experience = namedtuple("Experience", field_names=["prev_state","state", "action", "reward", "next_state", "done"])

# %%
def compute_loss(experiences, gamma, q_network, target_q_network):

    prev_states,states,rewards, next_states, done_vals,actions = experiences
    da=[states,next_states]
    max_qsa = tf.reduce_max(target_q_network(da), axis=-1)
    y_targets =rewards + (gamma * max_qsa * (1 - done_vals))
    da=[prev_states,actions]
    print("hello",da)
    q_values = q_network(da)
    # q_values = tf.gather_nd(q_values,tf.concat((next_states,actions),axis=1))    
    loss = MSE(y_targets, q_values)
    print("  Loss :-",loss)
    
    return loss

# %%
@tf.function
def agent_learn(experiences, gamma):
    with tf.GradientTape() as tape:
        loss = compute_loss(experiences, gamma, q_network, target_q_network)

    gradients = tape.gradient(loss, q_network.trainable_variables)
    optimizer.apply_gradients(zip(gradients, q_network.trainable_variables))

    # for target_weights, q_net_weights in zip(
    #     target_q_network.weights, q_network.weights
    # ):
    #     target_weights.assign(TAU * q_net_weights + (1.0 - TAU) * target_weights)

# %%
@tf.function
def update_agent():
    for target_weights, q_net_weights in zip(
        target_q_network.weights, q_network.weights
    ):
        target_weights.assign(TAU * q_net_weights + (1.0 - TAU) * target_weights)

# %%
num_games=10000
num_moves=3000

total_point_history = []
total_step_history = []

num_p_av=30
epsilon=0
mini_batch_size=512

learning_interval=5

target_q_network.set_weights(q_network.get_weights())

# %%
def getaction(env,epsilon):
    if np.random.rand() < epsilon and len(env.legal()) > 0:
        return env.legal()[np.random.randint(len(env.legal()))]
    else:
        q = []
        for i in env.legal():
            prev_state,da1,new_state,da2,action=env.stepc(i)
            # state_qn = np.concatenate((env.state(),action),axis=None)
            # state_qn=np.expand_dims(env.state(),axis=0)
            # prev_state=np.expand_dims(prev_state,axis=0)
            da=(prev_state,env.state())
            env.board.pop()
            q.append(q_network(da))
        if q == []:
            return None
        else:
            return env.legal()[np.argmax(q[:-1])]

# %%
def qupdate(t):
    if t % learning_interval == 0:
        return True
    else:
        return False

# %%
def get_experiences(mem):
    min=mini_batch_size
    try:
        batch=random.sample(mem,min)
    except:
        min=5
        batch=random.sample(mem,min)
    prev_state=np.zeros((min,64))
    states=np.zeros((min,64))
    rewards=np.zeros(min)
    next_states=np.zeros((min,64)) 
    done_vals=np.zeros(min)
    action=np.zeros((min,2))
    for i in range(min):
        # print('\n')
        # print(i)
        # print('\n')
        # print(batch[i])
        prev_state[i]=batch[i][0]
        states[i]=batch[i][1]
        rewards[i]=batch[i][2]
        next_states[i]=batch[i][3]
        done_vals[i]=batch[i][4]
        action[i]=batch[i][5]
    cbatch=(tf.convert_to_tensor(prev_state,dtype=tf.float32),
            tf.convert_to_tensor(states,dtype=tf.float32),
            tf.convert_to_tensor(rewards,dtype=tf.float32),
            tf.convert_to_tensor(next_states,dtype=tf.float32),
            tf.convert_to_tensor(done_vals,dtype=tf.float32),
            tf.convert_to_tensor(action,dtype=tf.float32))
    return cbatch

# %%
def get_new_eps(eps):
    eps=eps*0.95
    # if eps < 0.3:
    #     return 0.3
    return eps

# %%
import matplotlib.pyplot as plt

# %%
memory_buffer=deque(maxlen=MEMORY_SIZE)
for i in range(num_games):
    env=Envi("")
    total_points=0
    reward=0
    epsilon=0

    if i % 50 == 0:
        update_agent()
        epsilon=0.5

    for t in range(1,num_moves):
        state=env.state()
        print(f"\rEpisode {i+1} | Step {t} | last move point {reward}", end="")
        action=getaction(env,epsilon)
        if action==None:
            break
        prev_state,reward,next_state,done,action=env.step(action)
        # memory_buffer.append((state,action,reward,next_state,done))
        # if  t==20 or t==25 or t==30 or t==35 or t==40 or t==45:
        #     reward=reward-20000
        memory_buffer.append([prev_state,state,reward,next_state,done,action])

        update=qupdate(t)

        if update:
            experiences=get_experiences(memory_buffer)

            agent_learn(experiences,GAMMA)

        # clear_output()
        # display(total_point_history[-10:])
        # display(env.board)
        
        state=next_state
        total_points+=reward

        if done:
            env.board.outcome()
            total_step_history.append(t)
            break

    epsilon=get_new_eps(epsilon)
    
    total_point_history.append(total_points)
    av_latest_points=np.mean(total_point_history[-20:])
    env.board.outcome()

    # epsilon=get_new_eps(epsilon)

    if (i+1) % num_p_av == 0:
        print(f"\rEpisode {i+1} | Total point average of the last {num_p_av} episodes: {av_latest_points:.2f}")
        q_network.save(frontmodel)

    if av_latest_points >=300000.0:
        print(f"\n\nEnvironment solved in {i+1} episodes!")
        q_network.save(frontmodel)
        break
# Out:
# Episode 1 | Step 1 | last move point 0Computer move b8a6
# Episode 1 | Step 2 | last move point 50Computer move g8h6
# Episode 1 | Step 3 | last move point 50Computer move h6g4
# Episode 1 | Step 4 | last move point 50Computer move h8g8
# Episode 1 | Step 5 | last move point 50Computer move a8b8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[247], line 29
#      26 if update:
#      27     experiences=get_experiences(memory_buffer)
# ---> 29     agent_learn(experiences,GAMMA)
#      31 # clear_output()
#      32 # display(total_point_history[-10:])
#      33 # display(env.board)
#      35 state=next_state
#
# File ~/miniconda3/envs/tfg/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /tmp/__autograph_generated_filee4pyf62l.py:9, in outer_factory.<locals>.inner_factory.<locals>.tf__agent_learn(experiences, gamma)
#       7 with ag__.FunctionScope('agent_learn', 'fscope', ag__.ConversionOptions(recursive=True, user_requested=True, optional_features=(), internal_convert_user_code=True)) as fscope:
#       8     with ag__.ld(tf).GradientTape() as tape:
# ----> 9         loss = ag__.converted_call(ag__.ld(compute_loss), (ag__.ld(experiences), ag__.ld(gamma), ag__.ld(q_network), ag__.ld(target_q_network)), None, fscope)
#      10     gradients = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(loss), ag__.ld(q_network).trainable_variables), None, fscope)
#      11     ag__.converted_call(ag__.ld(optimizer).apply_gradients, (ag__.converted_call(ag__.ld(zip), (ag__.ld(gradients), ag__.ld(q_network).trainable_variables), None, fscope),), None, fscope)
#
# File /tmp/__autograph_generated_file6g16iuhz.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf__compute_loss(experiences, gamma, q_network, target_q_network)
#      10 (prev_states, states, rewards, next_states, done_vals, actions) = ag__.ld(experiences)
#      11 da = [ag__.ld(states), ag__.ld(next_states)]
# ---> 12 max_qsa = ag__.converted_call(ag__.ld(tf).reduce_max, (ag__.converted_call(ag__.ld(target_q_network), (ag__.ld(da),), None, fscope),), dict(axis=-1), fscope)
#      13 y_targets = ag__.ld(rewards) + ag__.ld(gamma) * ag__.ld(max_qsa) * (1 - ag__.ld(done_vals))
#      14 da = [ag__.ld(prev_states), ag__.ld(actions)]
#
# File ~/miniconda3/envs/tfg/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/tfg/lib/python3.9/site-packages/keras/engine/input_spec.py:298, in assert_input_compatibility(input_spec, inputs, layer_name)
#     296 if spec_dim is not None and dim is not None:
#     297     if spec_dim != dim:
# --> 298         raise ValueError(
#     299             f'Input {input_index} of layer "{layer_name}" is '
#     300             "incompatible with the layer: "
#     301             f"expected shape={spec.shape}, "
#     302             f"found shape={display_shape(x.shape)}"
#     303         )
#
# ValueError: in user code:
#
#     File "/tmp/ipykernel_2532/4203710705.py", line 4, in agent_learn  *
#         loss = compute_loss(experiences, gamma, q_network, target_q_network)
#     File "/tmp/ipykernel_2532/2586793030.py", line 5, in compute_loss  *
#         max_qsa = tf.reduce_max(target_q_network(da), axis=-1)
#     File "/home/avinash_23/miniconda3/envs/tfg/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler  **
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/avinash_23/miniconda3/envs/tfg/lib/python3.9/site-packages/keras/engine/input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 1 of layer "model_34" is incompatible with the layer: expected shape=(None, 2, 64), found shape=(5, 64)

# %%
import utils

# %%
utils.plot_history(total_point_history)

# %%
utils.plot_history(total_step_history)

# %%
update_agent()

# %%
q_network.save(frontmodel)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import pickle
with open('tokenizer_data.pkl','wb') as f:
    pickle.dump({'tokenizer':env.tokenizer},f)
